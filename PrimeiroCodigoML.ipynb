# %%
import pandas as pd
path = "/home/gregorio/Downloads/wine_dataset.csv"
arquivo = pd.read_csv(path)
arquivo.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality style
# 0      9.4        5   red
# 1      9.8        5   red
# 2      9.8        5   red
# 3      9.8        6   red
# 4      9.4        5   red

# %%
arquivo['style'] = arquivo['style'].replace('red', 0)

# %%
arquivo['style'] = arquivo['style'].replace('white', 1)

# %%
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  style
# 0      9.4        5      0
# 1      9.8        5      0
# 2      9.8        5      0
# 3      9.8        6      0
# 4      9.4        5      0

# %%
y= arquivo['style']
x=arquivo.drop('style', axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
from sklearn.ensemble import ExtraTreesClassifier
modelo = ExtraTreesClassifier()
modelo.fit(x_train, y_train)

resultado = modelo.score(x_test, y_test)
print("Acc: ", resultado)
# Out:
# Acc:  0.9989743589743589

# %%
y_test[400:403]
# Out:
# 4404    1
# 1033    0
# 384     0
# Name: style, dtype: int64

# %%
x_test[400:403]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 4404            7.3              0.20         0.26             1.6      0.040
# 1033            7.5              0.57         0.08             2.6      0.089
# 384             7.7              0.51         0.28             2.1      0.087
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 4404                 36.0                 123.0  0.99238  3.34       0.44
# 1033                 14.0                  27.0  0.99592  3.30       0.59
# 384                  23.0                  54.0  0.99800  3.42       0.74
#
#       alcohol  quality
# 4404     10.8        6
# 1033     10.4        6
# 384       9.2        5

# %%
previsoes = modelo.predict(x_test[400:403])

# %%
previsoes
# Out:
# array([1, 0, 0])
